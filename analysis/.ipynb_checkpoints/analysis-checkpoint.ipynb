# %% [markdown]
# # Delivery Order Analysis Task
# We provide a small data sample about a series of order deliveries extracted from a specific day.
#
# The homework requires to investigate it, by first answering a series of pre-defined questions, and then, by freely propose additional searches and analysis that will help understanding the data and extract other important insights.
#
# The resulting analysis should be presented with a Jupyter notebook, preferably with Python.
#
# ## Analysis
# * Number of drivers available in average per hour and for each order invitation. Any area in which we need to increase the coverage? maybe in a certain time range?
# * Statistics and quality of the automatic assignments. How is it working? Can you estimate its performance?
# * Quality of the estimation time the driver will take to arrive at the pick-up and drop-off (called estimated_arrival in the JSON). This is a value that is estimated by our Dispatcher algorithm. How is it doing our estimator?
# * Drivers Performance: avg. time to accept a job, avg. rejection (i.e., order that goes in timeout because not accepted), avg. time for delivery, any other?
# Note that these are kind of Business Questions: there can be cases in which there is not an easy/possible answer, but also cases that lead to deeper investigations and new questions.

# %%
# imports

# %matplotlib inline

import json
import pprint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
from datetime import datetime, timedelta


pp = pprint.PrettyPrinter(indent=4)

# %%
# read data
data = []
with open('./orders-2018-01-27.log') as f:
    for line in f:
        data.append(json.loads(line.encode('utf-8')))
        
# pp.pprint(data[0])

# %% [markdown]
# ## Data exploration

# %%
# An arbitrary JSON

pp.pprint(data[4])
# Out:
# {   u'_id': {   u'$oid': u'5a6c6552fe78590001016128'},
#     u'_keywords': [   u'1be',
#                       u'500516241',
#                       u'9ph',
#                       u'abdouh',
#                       u'com',
#                       u'greenford',
#                       u'hotmail',
#                       u'kfc',
#                       u'messari',
#                       u'omar',
#                       u'ramo921',
#                       u'ub6',
#                       u'w7'],
#     u'auto_assignment_count': 0,
#     u'cash_on_delivery': False,
#     u'company_id': {   u'$oid': u'5a42bc1f755ec20001abf5d8'},
#     u'created_at': {   u'$date': u'2018-01-27T11:41:06.650+0000'},
#     u'delivery_done_at': {   u'$date': u'2018-01-27T12:19:16.602+0000'},
#     u'dispatch_current_rank': {   u'base_version': u'88f93aad25910143af3215fb3d86caea',
#                                   u'driver_id': u'59dd48a9d502cf00014e2139',
# ...

# %%
# order id
print("id:" + "\t\t\t" + data[4]["_id"]["$oid"])

# driver id
print("driver id: " + "\t\t" + data[4]["dispatch_current_rank"]["driver_id"])

# created
print("created at: " + "\t\t" + data[4]["created_at"]["$date"])

# estimated
print("estimated: " + "\t\t" + data[4]["estimated_time"]["$date"])

# pick up done
print("pick up done at: " + "\t" + data[4]["pickup_done_at"]["$date"])

# delivery
print("delivered at: " + "\t\t" + data[4]["delivery_done_at"]["$date"])
# Out:
# id:			5a6c6552fe78590001016128
# driver id: 		59dd48a9d502cf00014e2139
# created at: 		2018-01-27T11:41:06.650+0000
# estimated: 		2018-01-27T12:25:00.000+0000
# pick up done at: 	2018-01-27T12:09:50.678+0000
# delivered at: 		2018-01-27T12:19:16.602+0000

# %%
# pp.pprint(data[0]["plan_route_request"])
# pp.pprint(data[0]["plan_route_response"])

# %%
# convert to pandas dataframe
df = pd.DataFrame(data)

# %%
# data wrangling

for index, row in df.iterrows():
    
    # creating dates
    
    dt_created_at = datetime.strptime(row['created_at']['$date'][:-5],'%Y-%m-%dT%H:%M:%S.%f')
    df.loc[index,'dt_created_at'] = dt_created_at
    
    # we can use the hour resolution to link each order to an hour-range
    df.loc[index,'dt_created_at_min'] = dt_created_at.replace(minute=0, second=0, microsecond=0)
    
    if row['pickup_done_at'] > 0:
        dt_pickup_done_at = datetime.strptime(row['pickup_done_at']['$date'][:-5],'%Y-%m-%dT%H:%M:%S.%f')
        df.loc[index,'dt_pickup_done_at'] = dt_pickup_done_at  
    
    if row['delivery_done_at'] > 0:
        dt_delivery_done_at = datetime.strptime(row['delivery_done_at']['$date'][:-5],'%Y-%m-%dT%H:%M:%S.%f')
        df.loc[index,'dt_delivery_done_at'] = dt_delivery_done_at
        
    dt_estimated_arrival = datetime.strptime(row['estimated_time']['$date'][:-5],'%Y-%m-%dT%H:%M:%S.%f')
    df.loc[index, 'dt_estimated_arrival'] = dt_estimated_arrival
    
    # if row['dispatch_current_rank']:
    #     try:
    #         last_job = row['dispatch_current_rank']['jobs'][-1]
    #         dt_estimated_arrival = datetime.strptime(last_jobs['estimated_arrival']['$date'][:-5],'%Y-%m-%dT%H:%M:%S.%f')
    #     except:
    #         dt_estimated_arrival = datetime.strptime(row['estimated_time']['$date'][:-5],'%Y-%m-%dT%H:%M:%S.%f')
    #     df.loc[index, 'dt_estimated_arrival'] = dt_estimated_arrival
        
    delivery_time = (dt_delivery_done_at-dt_created_at).total_seconds()/60
    df.loc[index, 'delivery_time'] = delivery_time

    delay_time = (dt_delivery_done_at-dt_estimated_arrival).total_seconds()/60
    df.loc[index, 'delay_time'] = delay_time
    
    if delay_time > 0:
        df.loc[index, 'delayed'] = 1
    else:
        df.loc[index, 'delayed'] = 0        
        
    # creating order id
    
    if row['_id']:
        try:
            _id = row['_id']['$oid']
        except:
            _id = row['_id']
        df.loc[index, '_id'] = _id
        
        
    # creating service area id
    
    if row['service_area_id']:
        try:
            area_id = row['service_area_id']['$oid']
        except:
            area_id = row['service_area_id']
        df.loc[index, 'area_id'] = area_id
        
    # creating the driver id
    
    if row["dispatch_current_rank"]["driver_id"]:
        try:
            driver_id = row["dispatch_current_rank"]["driver_id"]["$oid"]
        except:
            driver_id = row["dispatch_current_rank"]["driver_id"]
        df.loc[index, 'driver_id'] = driver_id
    
df.tail(3)
# Out:
#                           _id  \
# 349  5a6cf6ce38eb7f00019e11ec
# 350  5a6cf7900c0888000154b21a
# 351  5a6cf87d45fc9000016f172b
#
#                                              _keywords  auto_assignment_count  \
# 349  [3nb, 4060589, 4np, 5ea4d0b0663549ccb7af343d76...                      0
# 350  [1ss, 501010770, 6ah, com, ha0, ha9, javed, kf...                      0
# 351  [2ln, 501013121, 6ah, com, domingues, gmail, h...                      0
#
#      cash_on_delivery                              company_id  \
# 349             False  {u'$oid': u'5a42bc1f755ec20001abf5d8'}
# 350             False  {u'$oid': u'5a42bc1f755ec20001abf5d8'}
# 351             False  {u'$oid': u'5a42bc1f755ec20001abf5d8'}
#
#                                       created_at  \
# 349  {u'$date': u'2018-01-27T22:01:50.316+0000'}
# 350  {u'$date': u'2018-01-27T22:05:04.044+0000'}
# 351  {u'$date': u'2018-01-27T22:09:01.770+0000'}
#
#                                 delivery_done_at  \
# ...

# %%
# time history of data

print(df['dt_created_at'].min())
print(df['dt_created_at'].max())

print(df['dt_delivery_done_at'].min())
print(df['dt_delivery_done_at'].max())
# Out:
# 2018-01-25 18:53:43.873000
# 2018-01-27 22:09:01.770000
# 2018-01-25 20:30:02.533000
# 2018-01-27 22:40:55.784000

# %%
# there are only 4 different areas
print('Number of areas: ' + '\t' + str(len(df['area_id'].unique())))

# there are 40 different drivers
print('Number of drivers: ' + '\t' + str(len(df['driver_id'].unique())))

# there are 352 observations (= )
print('Number of orders: ' + '\t' + str(len(df['_id'].unique())))

print('\nNumber of Drivers per Area')
print(df.groupby('area_id')['driver_id'].nunique().reset_index())
# Out:
# Number of areas: 	4
# Number of drivers: 	40
# Number of orders: 	352
#
# Number of Drivers per Area
#                     area_id  driver_id
# 0  59d74a180d73470001565cd1          6
# 1  59ef610c7e94fe000185da42         24
# 2  59ef61bf7e94fe000185da43          6
# 3  59ef6b21366e6500018bc9b9          4

# %%
# df.sort_values(by=['dif_min_delivery_estimated'], ascending=False)
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')
plt.hist(df['delay_time'], bins=range(-60, 60, 1), rwidth=0.6)
plt.title('Histogram of Delayed Orders (Time Difference between Delivery and Estimated Arrival Time)')
plt.xlabel('Minutes Delayed (+ delayed, - in time)')
plt.ylabel('# of Orders')
plt.show()

# %% [markdown]
# We can observe that the majority of the orders are delivered before the estimated arrival time. There are some orders delivered after the estimated arrival time. It seems reasonable to consider that"as delayed" orders delivered 5 minutes later than originally scheduled.

# %%
# all possible combinations of date of order creation and area id
idx = pd.MultiIndex.from_product((df['dt_created_at_min'].unique(), df['area_id'].unique()))

# ppd = df.groupby(['dt_created_at_min','area_id']).count().reindex(idx)

df2 = df.groupby([df['dt_created_at_min'], df['area_id']], as_index=False)['_id'].count()

df1 = pd.DataFrame(idx, columns=['temp'])
for index, row in df1.iterrows():
    df1.loc[index,'dt_created_at_min'] = row[0][0]
    df1.loc[index,'area_id'] = row[0][1]

df1 = df1.drop('temp', axis=1)
df_created_area = pd.merge(df1, df2, how='left', on=['dt_created_at_min','area_id'])

df_created_area.tail(8)

# focus on >= 20180127
df_created_area = df_created_area[df_created_area['dt_created_at_min'] > datetime(2018,1,27,10)]

plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

x = df_created_area['dt_created_at_min'].unique()

v = df_created_area[df_created_area['area_id']=='59ef610c7e94fe000185da42']['_id']
u = df_created_area[df_created_area['area_id']=='59ef61bf7e94fe000185da43']['_id']
y = df_created_area[df_created_area['area_id']=='59ef6b21366e6500018bc9b9']['_id']
z = df_created_area[df_created_area['area_id']=='59d74a180d73470001565cd1']['_id']

w = 700000000000 # time offset for plotting bars of different areas (not really elegant ...)

ax = plt.subplot(111)
ax.bar(x,     v, width=0.0075, align='edge')
ax.bar(x+w,   u, width=0.0075, color='g', align='edge')
ax.bar(x+2*w, y, width=0.0075, color='r', align='edge')
ax.bar(x+3*w, z, width=0.0075, color='y', align='edge')

ax.legend(('59ef610c7e94fe000185da42', '59ef61bf7e94fe000185da43', '59ef6b21366e6500018bc9b9', '59d74a180d73470001565cd1'), loc='upper left')
ax.xaxis_date()


plt.ylabel("Number of Orders")
plt.title('Distribution of Orders by Service Area and Time Interval')

plt.show()

# %% [markdown]
# It can be clearly seen that the blue service area has the majority of the orders (most of the time, at each hour, the volume of deliveries made in the blue area is larger than the total volume of deliveries in the rest of the other areas).

# %%
# Temporal distribution of orders by Area and Hour Interval

f, axarr = plt.subplots(2, 2, figsize=(15,15))

area = '59ef610c7e94fe000185da42'
df2 = df[df['area_id']==area][['driver_id', 'dt_created_at', 'dt_delivery_done_at']]
df2 = df2.dropna()
df2.amin = pd.to_datetime(df2['dt_created_at']).astype(datetime)
df2.amax = pd.to_datetime(df2['dt_delivery_done_at']).astype(datetime)
axarr[0, 0].hlines(df2.index, date2num(df2.amin), date2num(df2.amax), color='b')
axarr[0, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 0].set_title('59ef610c7e94fe000185da42')
axarr[0, 0].set_ylabel('Drivers')

area = '59ef61bf7e94fe000185da43'
df2 = df[df['area_id']==area][['driver_id', 'dt_created_at', 'dt_delivery_done_at']]
df2 = df2.dropna()
df2.amin = pd.to_datetime(df2['dt_created_at']).astype(datetime)
df2.amax = pd.to_datetime(df2['dt_delivery_done_at']).astype(datetime)
axarr[0, 1].hlines(df2.index, date2num(df2.amin), date2num(df2.amax), color='g')
axarr[0, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 1].set_title('59ef61bf7e94fe000185da43')

area = '59ef6b21366e6500018bc9b9'
df2 = df[df['area_id']==area][['driver_id', 'dt_created_at', 'dt_delivery_done_at']]
df2 = df2.dropna()
df2.amin = pd.to_datetime(df2['dt_created_at']).astype(datetime)
df2.amax = pd.to_datetime(df2['dt_delivery_done_at']).astype(datetime)
axarr[1, 0].hlines(df2.index, date2num(df2.amin), date2num(df2.amax), color='r')
axarr[1, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 0].set_title('59ef6b21366e6500018bc9b9')
axarr[1, 0].set_ylabel('Drivers')

area = '59d74a180d73470001565cd1'
df2 = df[df['area_id']==area][['driver_id', 'dt_created_at', 'dt_delivery_done_at']]
df2 = df2.dropna()
df2.amin = pd.to_datetime(df2['dt_created_at']).astype(datetime)
df2.amax = pd.to_datetime(df2['dt_delivery_done_at']).astype(datetime)
axarr[1, 1].hlines(df2.index, date2num(df2.amin), date2num(df2.amax), color='y')
axarr[1, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 1].set_title('59d74a180d73470001565cd1')

plt.show()

# %% [markdown]
# There are no further conclusions that can be extracted from charts:
# * blue area has way more orders
# * perhaps the yellow area (`59d74a180d73470001565cd1`) seems to experiment longer delivery times (from order creation to delivery)

# %%
print('')
print('Mean of Delivery Time per Area')
print('*'*50)
print(df.groupby('area_id')['delivery_time'].mean())
print('')

# compute the mean of the delay time per area (leave out non-delayed orders)
print('Mean of Delay Time per Area')
print('*'*50)
print(df[df['delayed']==1].groupby('area_id')['delay_time'].mean())
# Out:
# Mean of Delivery Time per Area
# **************************************************
# area_id
# 59d74a180d73470001565cd1    40.471838
# 59ef610c7e94fe000185da42    31.494594
# 59ef61bf7e94fe000185da43    31.624421
# 59ef6b21366e6500018bc9b9    25.281417
# Name: delivery_time, dtype: float64
#
# Mean of Delay Time per Area
# **************************************************
# area_id
# 59d74a180d73470001565cd1    15.590210
# 59ef610c7e94fe000185da42    10.839039
# 59ef61bf7e94fe000185da43    14.635731
# 59ef6b21366e6500018bc9b9     8.695783
# Name: delay_time, dtype: float64

# %% [markdown]
# * Yes, there is correlation between longer delivery times and delays.
# * The order of magnitude of these timings seems reasonable.

# %% [markdown]
# ## Number of drivers available per hour interval and service area
#
# Number of drivers available in average per hour and for each order invitation. Any area in which we need to increase the coverage? maybe in a certain time range?
#
# __Assumptions__
#
# * Any driver can be assigned to any order at any time (= constant amount of drivers throughout the day).
# * A driver is not available in an hour interval if assigned to an order during that hour interval (in other words, a driver is 100% available in an hour interval if there are no orders assigned to him/her until, at least, the next hour interval).
# * The total amount of drivers for a specfic area is calculated by taking into account all drivers assigned to orders originated at that particular area.
#
# __Caveats__
#
# * There might be cases where a delivery only consumes a small fraction of an hour interval and despite this fact we are considering that the driver is occupied throughout the whole hour interval (which is not entirely true).
# * Drivers who operate in multiple areas ...
# * Drivers who do not work during the whole day ...
#
# __Approach__
#
# Based on these assumptions I can approximate how many drivers are available (= total drivers - drivers assigned to new deliveries) for each hour interval and service area.

# %%
df.loc[322]['_id']
# Out:
# u'5a6ce80023f40b00011e7142'

# %%
for index, row in df.iterrows():
    n_drivers = 1 # current driver
    if row['dispatch_driver_ranking']: # the current driver does not overlap with drivers in ranking 
        print(index, len(row['dispatch_driver_ranking']))
        n_drivers += len(row['dispatch_driver_ranking'])
    # df.loc[index, 'n_drivers'] = n_drivers
# Out:
# (8, 1)
# (10, 1)
# (11, 4)
# (12, 3)
# (13, 1)
# (14, 3)
# (15, 1)
# (16, 4)
# (17, 3)
# (18, 2)
# (19, 3)
# (20, 3)
# (21, 2)
# (22, 2)
# (23, 3)
# (24, 4)
# (25, 3)
# (26, 4)
# (27, 2)
# (29, 1)
# (30, 3)
# (31, 1)
# (32, 2)
# (33, 3)
# (34, 1)
# (35, 3)
# (36, 2)
# (38, 2)
# (39, 1)
# (40, 1)
# (42, 3)
# (43, 2)
# (44, 3)
# (45, 2)
# (48, 2)
# (49, 4)
# (50, 1)
# (51, 2)
# (52, 3)
# (53, 2)
# (55, 3)
# (56, 3)
# (57, 2)
# (58, 2)
# (59, 2)
# (60, 2)
# (61, 2)
# (62, 2)
# (63, 1)
# (64, 1)
# (65, 3)
# (66, 1)
# (67, 1)
# (68, 2)
# (69, 2)
# (70, 1)
# (71, 2)
# (72, 3)
# (73, 3)
# (74, 1)
# (76, 3)
# (77, 2)
# (78, 3)
# (79, 3)
# (81, 2)
# (82, 1)
# (83, 2)
# (84, 1)
# (85, 3)
# (86, 1)
# (87, 1)
# (89, 3)
# (90, 1)
# (91, 1)
# (92, 1)
# (93, 1)
# (94, 2)
# (95, 3)
# (96, 4)
# (97, 2)
# (98, 2)
# (99, 2)
# (100, 5)
# (101, 1)
# (103, 2)
# (104, 2)
# (105, 2)
# (106, 4)
# (107, 4)
# (108, 5)
# (109, 2)
# (110, 5)
# (111, 2)
# (113, 5)
# (114, 2)
# (115, 5)
# (116, 5)
# (117, 3)
# ...

# %%
# count unique drivers per time interval and service area (drivers working)

indx = df.groupby([df['dt_created_at_min'], df['area_id']])['driver_id'].nunique().index.names
df2 = pd.DataFrame(pd.Series(df.groupby([df['dt_created_at_min'], df['area_id']])['driver_id'].nunique()))
df2.reset_index(inplace=True)  
df2 = df2.rename(columns={'driver_id':'nunique_drivers_working'})

df_drivers_working = pd.merge(df1, df2, how='left', on=['dt_created_at_min','area_id'])

# %%
# focus on 2018-01-27 (plot)

df_drivers_working_plt = df_drivers_working[df_drivers_working['dt_created_at_min'] > datetime(2018,1,27,10)]

plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

x = df_drivers_working_plt['dt_created_at_min'].unique()

v = df_drivers_working_plt[df_drivers_working_plt['area_id']=='59ef610c7e94fe000185da42']['nunique_drivers_working']
u = df_drivers_working_plt[df_drivers_working_plt['area_id']=='59ef61bf7e94fe000185da43']['nunique_drivers_working']
y = df_drivers_working_plt[df_drivers_working_plt['area_id']=='59ef6b21366e6500018bc9b9']['nunique_drivers_working']
z = df_drivers_working_plt[df_drivers_working_plt['area_id']=='59d74a180d73470001565cd1']['nunique_drivers_working']

w = 700000000000 # time offset for plotting bars of different areas

ax = plt.subplot(111)
ax.bar(x,     v, width=0.0075, align='edge')
ax.bar(x+w,   u, width=0.0075, color='g', align='edge')
ax.bar(x+2*w, y, width=0.0075, color='r', align='edge')
ax.bar(x+3*w, z, width=0.0075, color='y', align='edge')

ax.legend(('59ef610c7e94fe000185da42', '59ef61bf7e94fe000185da43', '59ef6b21366e6500018bc9b9', '59d74a180d73470001565cd1'), loc='upper left')
ax.xaxis_date()


plt.ylabel("Number of Drivers Working")
plt.title('Distribution of Drivers (distinct) assigned to Orders by Service Area and Time Interval (= drivers working)')

plt.show()

# %% [markdown]
# We should see less drivers available during the night shift (between 17:00 to 21:00) since there is a high demand of deliveries.

# %%
# let's now count the total amount of drivers for each service area.
df_drivers_total = df.groupby('area_id')['driver_id'].nunique().reset_index()
df_drivers_total = df_drivers_total.rename(columns={'driver_id':'nunique_drivers_total'})

# merging these two dataframes will allow us to see the number of drivers working vs total drivers
df_drivers = pd.merge(df_drivers_working, df_drivers_total, how='left', on=['area_id'])
df_drivers = df_drivers.replace(np.nan, 0)

# drivers available
df_drivers['nunique_drivers_avail'] = df_drivers.apply(lambda x: (x['nunique_drivers_total']-x['nunique_drivers_working']), axis=1)

# df_drivers.head(10)

# %%
# number of drivers available in average per hour interval 
# (the date shown in the table is the origin of a 1-hour interval)
df_drivers.groupby('dt_created_at_min')['nunique_drivers_avail'].mean().reset_index()
# Out:
#      dt_created_at_min  nunique_drivers_avail
# 0  2018-01-25 18:00:00                   9.75
# 1  2018-01-26 21:00:00                   9.75
# 2  2018-01-27 11:00:00                   8.50
# 3  2018-01-27 12:00:00                   5.75
# 4  2018-01-27 13:00:00                   6.50
# 5  2018-01-27 14:00:00                   5.50
# 6  2018-01-27 15:00:00                   5.00
# 7  2018-01-27 16:00:00                   2.50
# 8  2018-01-27 17:00:00                   3.75
# 9  2018-01-27 18:00:00                   1.75
# 10 2018-01-27 19:00:00                   1.25
# 11 2018-01-27 20:00:00                   2.50
# 12 2018-01-27 21:00:00                   5.25
# 13 2018-01-27 22:00:00                   9.25

# %%
# number of drivers available in average per hour and area

f, axarr = plt.subplots(2, 2, figsize=(15,15))

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef610c7e94fe000185da42']['nunique_drivers_avail']
axarr[0, 0].bar(x, y, width=0.03, align='edge')
axarr[0, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 0].set_title('59ef610c7e94fe000185da42')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef61bf7e94fe000185da43']['nunique_drivers_avail']
axarr[0, 1].bar(x, y, width=0.03, align='edge', color='g')
axarr[0, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 1].set_title('59ef61bf7e94fe000185da43')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef6b21366e6500018bc9b9']['nunique_drivers_avail']
axarr[1, 0].bar(x, y, width=0.03, align='edge', color='r')
axarr[1, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 0].set_title('59ef6b21366e6500018bc9b9')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59d74a180d73470001565cd1']['nunique_drivers_avail']
axarr[1, 1].bar(x, y, width=0.03, align='edge', color='y')
axarr[1, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 1].set_title('59d74a180d73470001565cd1')

axarr[0, 0].set_ylabel('Number of Available Drivers')
axarr[1, 0].set_ylabel('Number of Available Drivers')

plt.show()

# %% [markdown]
# The number of available drivers just shows us one half of the picture...
# In order to see if we need to increase the coverage we need to check whether the performance is not good at some moment or area (i.e. the concentration of delays).
#
# To this end, we can compute the % of orders delayed for each hour interval and area. In order to contrast these findings with the number of available drivers, we will anchor these percentages (orders delayed) to the order creation timestamp (hour interval).

# %%
# df.groupby(['dt_created_at_min', 'area_id', 'delayed'])['_id'].count().reset_index()

for index, row in df_drivers.iterrows():
    df_temp = df[(df['dt_created_at_min']==row['dt_created_at_min']) & (df['area_id']==row['area_id'])]
    df_drivers.loc[index, 'n_orders_delayed'] = df_temp[df_temp['delayed']==1]['delayed'].sum()
    df_drivers.loc[index, 'n_orders'] = df_temp['delayed'].count()
    if df_temp['delayed'].count() > 0:
        df_drivers.loc[index, 'perc_orders_delayed'] = df_temp[df_temp['delayed']==1]['delayed'].sum()/df_temp['delayed'].count()
    else:
        df_drivers.loc[index, 'perc_orders_delayed'] = 0
    
# df_drivers

# %%
# check values (OK)

print('Total number of orders: ' + '\t' + str(df_drivers['n_orders'].sum()))
print('Total number of orders delayed: ' + str(df_drivers['n_orders_delayed'].sum()))
# Out:
# Total number of orders: 	352.0
# Total number of orders delayed: 67.0

# %%
# number of drivers available in average per hour and area

f, axarr = plt.subplots(2, 2, figsize=(15,15))

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef610c7e94fe000185da42']['perc_orders_delayed']
axarr[0, 0].bar(x, y, width=0.03, align='edge')
axarr[0, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 0].set_ylim(0, 1)
axarr[0, 0].set_title('59ef610c7e94fe000185da42')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef61bf7e94fe000185da43']['perc_orders_delayed']
axarr[0, 1].bar(x, y, width=0.03, align='edge', color='g')
axarr[0, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 1].set_ylim(0, 1)
axarr[0, 1].set_title('59ef61bf7e94fe000185da43')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef6b21366e6500018bc9b9']['perc_orders_delayed']
axarr[1, 0].bar(x, y, width=0.03, align='edge', color='r')
axarr[1, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 0].set_ylim(0, 1)
axarr[1, 0].set_title('59ef6b21366e6500018bc9b9')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59d74a180d73470001565cd1']['perc_orders_delayed']
axarr[1, 1].bar(x, y, width=0.03, align='edge', color='y')
axarr[1, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 1].set_ylim(0, 1)
axarr[1, 1].set_title('59d74a180d73470001565cd1')

axarr[0, 0].set_ylabel('% of Orders Delayed')
axarr[1, 0].set_ylabel('% of Orders Delayed')

plt.show()

# %%
# number of drivers available in average per hour and area

f, axarr = plt.subplots(2, 2, figsize=(15,15))

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef610c7e94fe000185da42']['n_orders']
axarr[0, 0].bar(x, y, width=0.03, align='edge')
axarr[0, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 0].set_ylim(0, 34)
axarr[0, 0].set_title('59ef610c7e94fe000185da42')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef61bf7e94fe000185da43']['n_orders']
axarr[0, 1].bar(x, y, width=0.03, align='edge', color='g')
axarr[0, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[0, 1].set_ylim(0, 34)
axarr[0, 1].set_title('59ef61bf7e94fe000185da43')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59ef6b21366e6500018bc9b9']['n_orders']
axarr[1, 0].bar(x, y, width=0.03, align='edge', color='r')
axarr[1, 0].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 0].set_ylim(0, 34)
axarr[1, 0].set_title('59ef6b21366e6500018bc9b9')

x = df_drivers['dt_created_at_min'].unique()
y = df_drivers[df_drivers['area_id']=='59d74a180d73470001565cd1']['n_orders']
axarr[1, 1].bar(x, y, width=0.03, align='edge', color='y')
axarr[1, 1].set_xlim(datetime(2018,1,27,11,0,0),datetime(2018,1,27,23,0,0))
axarr[1, 1].set_ylim(0, 34)
axarr[1, 1].set_title('59d74a180d73470001565cd1')

axarr[0, 0].set_ylabel('Number of Orders')
axarr[1, 0].set_ylabel('Number of Orders')

plt.show()

# %% [markdown]
# ## Conclusions
#
# So far the analysis yields the following conclusions:
# * In general, it is during the dinner that there are more orders taken. There are less drivers available and more delays.
#
# ### Good performer
# * Without a doubt, the red service area (`59ef6b21366e6500018bc9b9`), which has a similar demand compared to green and yellow areas, has barely no delays. It seems that the performance is highly efficient because there are no drivers available during the afternoon/evening (i.e., they are all working) and deliveries are always in time.
#
# ### Bad performers
# * The worst area is the yellow one (`59d74a180d73470001565cd1`). There are consistent delays throughout the day, specially during the lunch and dinner time. The average delay time is roughly 16 minutes and the deliveries take longer than any other area to end (40 minutes). There are just a few drivers available in high-demand hours and yet the delays are always present. An increase in coverage should be considered for this area.
#
# * The blue area (`59ef610c7e94fe000185da42`) is the one that generates more orders and concentrates more drivers. There are larger delays during the dinner time and just a few spare drivers. A better coverage or a much more efficient allocation of drivers seems to be the solution to meet the customers needs.

# %% [markdown]
# # Statistics and Quality of Automatic Assignments
#
# Statistics and quality of the automatic assignments. How is it working? Can you estimate its performance?
#
# __Assumptions__
#
# * Automatic assignments are those orders where drivers have NOT been assigned manually (`dispatch_current_rank.warnings`).
#
# __Approach__
#
# I will check the frequency of the different types of warnings of all automatic orders.

# %%
# the great majority of orders only have 2 jobs (pick-up and delivery)
# there are a few orders that have more than 2 jobs and will not be considered here ...

for index, row in df.iterrows():
    if row['dispatch_current_rank']['warnings']:
        if row['dispatch_current_rank']['warnings'][0] == 'driver_assigned_manually':
            df.loc[index, 'manual_assign'] = 1
    else:
        df.loc[index, 'manual_assign'] = 0
        jobs = row['dispatch_current_rank']['jobs']
        if len(jobs) == 2:
            # sort jobs in ascending order (by estimated_arrival time)
            jobs.sort(key=lambda item:item['estimated_arrival'], reverse=False)
            
            # first job is pickup
            dt_dispatch_pickup = datetime.strptime(jobs[0]['estimated_arrival'][:-1],'%Y-%m-%dT%H:%M:%S.%f')
            
            # second job is dropoff
            dt_dispatch_dropoff = datetime.strptime(jobs[1]['estimated_arrival'][:-1],'%Y-%m-%dT%H:%M:%S.%f')
            
            df.loc[index, 'dt_dispatch_pickup'] = dt_dispatch_pickup
            df.loc[index, 'dt_dispatch_dropoff'] = dt_dispatch_dropoff

df.head(3)
# Out:
#                         _id  \
# 0  5a6a27b7107a1e0001ccbd30
# 1  5a6b9a57fe78590001016003
# 2  5a6c5bb2fe78590001016115
#
#                                            _keywords  auto_assignment_count  \
# 0  [4032445, 6ah, 8fd, b22067c9af434714b2c8bba323...                      0
# 1  [3nb, 4046761, aaee0648d6ae40ccb2f80971989b9d0...                      0
# 2  [1fu, 22ebee36141b4da7be7c013f2e79404c, 404709...                      0
#
#    cash_on_delivery                              company_id  \
# 0             False  {u'$oid': u'5a42bc1f755ec20001abf5d8'}
# 1             False  {u'$oid': u'5a42bc1f755ec20001abf5d8'}
# 2             False  {u'$oid': u'5a42bc1f755ec20001abf5d8'}
#
#                                     created_at  \
# 0  {u'$date': u'2018-01-25T18:53:43.873+0000'}
# 1  {u'$date': u'2018-01-26T21:15:03.928+0000'}
# 2  {u'$date': u'2018-01-27T11:00:02.583+0000'}
#
#                               delivery_done_at  \
# 0  {u'$date': u'2018-01-25T20:30:02.533+0000'}
# ...

# %%
# dispatcher warnings (automatic assignments quality)
# Note: one order can have more than one warning

n_orders_automatic = df['dt_dispatch_pickup'].count() # number of automatic orders with 2 jobs scheduled
print("\nTotal amount of automatic orders:\n" + str(n_orders_automatic))

x_warning = []
for warning_list in df['warnings']:
    for warning in warning_list:
        x_warning.append(warning)
        
warnings_unique = list(set(x_warning))

for warning in warnings_unique:
    for index, row in df.iterrows():
        df.loc[index, warning] = 0
        if row['warnings']:
            for r_warning in row['warnings']:
                if warning == r_warning:
                    df.loc[index, warning] = 1
print("")
p_warning = []
for warning in warnings_unique:                    
    print(warning + ": \n" + str("{0:.0f}".format(df[warning].sum())) + " (" + str("{0:.2f}".format(df[warning].sum()/n_orders_automatic*100)) + "%)\n")
    p_warning.append(df[warning].sum()/n_orders_automatic*100)
    
fig, ax = plt.subplots()

y_pos = np.arange(len(warnings_unique))

ax.barh(y_pos, p_warning, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(warnings_unique)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('% of Automatic Orders')
ax.set_xlim(0,100)
ax.set_title('Warnings in Automatic Assignments')

plt.show()
# Out:
# Total amount of automatic orders:
# 331
#
# order_invite_rejected:
# 33 (9.97%)
#
# order_dispatch_select_driver_version_conflict:
# 113 (34.14%)
#
# dispatcher_unfeasible_driver:
# 18 (5.44%)
#
# dispatcher_overdue_order:
# 7 (2.11%)
#
# order_invite_timeout:
# 200 (60.42%)
#
# dispatcher_no_driver_in_radius:
# 6 (1.81%)
#
# dispatcher_all_drivers_discarded:
# 2 (0.60%)

# %% [markdown]
# * It can be seen that more than a half of all automatic orders are rejected (order that goes in timeout because not accepted).
# * Further, the automatic assignment engine seems to have some conflicts with driver version (34% of orders).

# %%
warnings_delay = []
for warning in warnings_unique:
    warnings_delay.append(df[df[warning]==1]['delayed'].mean()*100)

fig, ax = plt.subplots()

y_pos = np.arange(len(warnings_unique))

ax.barh(y_pos, warnings_delay, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(warnings_unique)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('% of Delayed Orders')
ax.set_xlim(0,100)
ax.set_title('Delays in Automatic Assignments by Warning Type')

plt.show()

# %% [markdown]
# Trying to find causality - relationship between warnings and observed delays ......

# %%
# Distribution of drivers assigned to an order (= drivers not available) per hour
# df.groupby('dt_created_at_min')['driver_id'].nunique()

idx = pd.MultiIndex.from_product((df['driver_id'].unique(), df['dt_created_at_min'].unique()))
df2 = df.groupby(['driver_id', 'dt_created_at_min'], as_index=False)['_id'].count()
df1 = pd.DataFrame(idx, columns=['temp'])
for index, row in df1.iterrows():
    df1.loc[index,'driver_id'] = row[0][0]
    df1.loc[index,'dt_created_at_min'] = row[0][1]

df1 = df1.drop('temp', axis=1)
df3 = pd.merge(df1, df2, how='left', on=['driver_id','dt_created_at_min'])


N = 50
x = df3['dt_created_at_min'].unique()

for driver in df3['driver_id'].unique():
    y = df3[df3['driver_id']==driver]['_id']
    area = np.pi*(10*df3[df3['driver_id']==driver]['_id'])**2
    plt.scatter(x, y, s=area, alpha=0.5)
    
# colors = np.random.rand(N)
# area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii
# plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.xlim(datetime(2018,1,27,8,0,0),datetime(2018,1,28,0,0,0))
plt.show()

# %% [raw]
# Now we can calculate the ratio of available drivers vs the total amount of deliveries and examine if there are certain areas or time intervals where:
#
# * there are just a few drivers available compared to the number of deliveries (low values of ratio)

# %%
# Distribution of drivers per hour


# _id = count of orders
# driver_id = count distinct of drivers
        
# xt = pd.merge(df_created_area, df_created_area_drivers, how='left',  on=['dt_created_at_min','area_id'])
# xt['drivers_per_orders'] = xt.apply(lambda x: (x['_id']/x['driver_id']), axis=1)
# xt.sort_values(by=['drivers_per_orders'])

# %% [markdown]
# # Questions

# %% [markdown]
# __Number of drivers available in average per hour and for each order invitation. Any area in which we need to increase the coverage? maybe in a certain time range?__

# %%
#plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')
#plt.hist(df['dt_created_at'].values)

# %%
# let's create first a pd series with all possible hours elapsed between the creation of the first and last order

s_range = pd.Series(pd.date_range(df['dt_created_at'].min().replace(minute=0, second=0, microsecond=0), df['dt_created_at'].max(), freq='1H'))
df_range = pd.DataFrame(s_range, columns=['dt_created_min'])

for index, row in df_range.iterrows():
    df_range.loc[index, 'dt_created_max'] = row['dt_created_min'] + timedelta(hours=1)
    
df_range.head(3)
# Out:
#        dt_created_min      dt_created_max
# 0 2018-01-25 18:00:00 2018-01-25 19:00:00
# 1 2018-01-25 19:00:00 2018-01-25 20:00:00
# 2 2018-01-25 20:00:00 2018-01-25 21:00:00

# %%
# for each hour range, let's check how many creations of orders are generated

for index, row in df_range.iterrows():
    dt_created_min = row['dt_created_min']
    dt_created_max = row['dt_created_max']
    n_orders_created = 0
    
    for index_d, row_d in df.iterrows():
        # if the order is created in this hour range ...
        if dt_created_min < row_d['dt_created_at'] and dt_created_max > row_d['dt_created_at']:
            # count number of drivers
            n_orders_created += 1
            #if row_d["dispatch_current_rank"]:
            #    try:
            #        print(row_d["dispatch_current_rank"]["driver_id"]["$oid"])
            #    except:
            #        print(row_d["dispatch_current_rank"]["driver_id"])
            
    df_range.loc[index, 'n_orders_created'] = n_orders_created

# %%
df_range['dt_created_min'].index
# Out:
# RangeIndex(start=0, stop=53, step=1)

# %%
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')
plt.bar(df_range['dt_created_min'].values, df_range['n_orders_created'], width=0.03, align='edge')
# Out:
# <Container object of 53 artists>

# %%
# let's focus on day 27
df_focus = df_range[df_range['dt_created_min'] > datetime(2018,1,27,10)]
df_focus.head(3)
# Out:
#         dt_created_min      dt_created_max  n_orders_created
# 41 2018-01-27 11:00:00 2018-01-27 12:00:00               7.0
# 42 2018-01-27 12:00:00 2018-01-27 13:00:00              20.0
# 43 2018-01-27 13:00:00 2018-01-27 14:00:00              16.0

# %%
plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')
plt.bar(df_focus['dt_created_min'].values, df_focus['n_orders_created'], width=0.03, align='edge')
# Out:
# <Container object of 12 artists>

# %% [markdown]
# Assumptions:
# * real_delivery_time: time elapsed between order creation and drop-off: __`( delivery_done_at - created_at )`__.
# * Only consider that a driver is not available in hour X if the real_delivery_time fully covers that specific hour.

# %%
df.head(1)
# Out:
#                                       _id  \
# 0  {u'$oid': u'5a6a27b7107a1e0001ccbd30'}
#
#                                            _keywords  auto_assignment_count  \
# 0  [4032445, 6ah, 8fd, b22067c9af434714b2c8bba323...                      0
#
#    cash_on_delivery                              company_id  \
# 0             False  {u'$oid': u'5a42bc1f755ec20001abf5d8'}
#
#                                     created_at  \
# 0  {u'$date': u'2018-01-25T18:53:43.873+0000'}
#
#                               delivery_done_at  \
# 0  {u'$date': u'2018-01-25T20:30:02.533+0000'}
#
#                                dispatch_current_rank dispatch_driver_ranking  \
# 0  {u'base_version': u'13dcd039f65106e18d478c0465...                    None
#
#   dispatch_status        ...                             service_provider_id  \
# 0        accepted        ...          {u'$oid': u'599f07665973744817af5bcf'}
#
#   twilio_reminders_count                                   updated_at  \
# ...
